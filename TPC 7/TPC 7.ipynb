# %% [markdown]
# ### TPC7: Construir uma aplicação para manipular polinómios
#
# Depois da aula da semana passada, já tens algumas funções desenvolvidas que te irão ajudar a construir a aplicação que se descreve a seguir.
#
# * Aquecimento: Instancia os seguintes exemplos num ficheiro de texto com o formato definido na última aula
#     - `x^7 - 3.7x^4 + 5x^3 - 88`
#     - `2x^2 + 17`
#     - `7x^4 + 6x^3 - x^2 + 43`
#     - `x^4`
#     - `x^2`
#     - `x^3`
#
# * Desenvolve as seguintes funcionalidades que não foram trabalhadas na aula:
#     1. Define uma função que dado um polinómio calcula a sua derivada;
#     2. Define uma função que recebe dois polinómios `p1` e `p2` e calcula um novo polinómio correspondente à soma de `p1` e `p2`;
#     3. Define uma função que recebe um polinómio e o desenha num gráfico.
#
# * Num ficheiro Python, cria uma aplicação para manipular polinómios com as seguintes operações:
#     1. Criar um polinómio interativamente;
#     2. Ler uma lista de polinómios de um ficheiro;
#     3. Listar polinómios: mostra numa tabela os polinómios carregados em memória, adicionando um número de ordem a cada um;
#     4. Calcular o valor de um polinómio num ponto (usa o número de ordem para referenciar o polinómio);
#     5. Listar polinómios com grau: à listagem anterior, acrescenta mais uma coluna com o grau;
#     6. Maior grau: mostra o polinómio de maior grau e indica o seu número de ordem;
#     7. Derivada: mostra uma tabela com os polinómios e as respetivas derivadas;
#     8. Somar dois polinómios: indicando os seus números de ordem;
#     9. Gerar um gráfico para o polinómio;
#     10. Gravar num ficheiro os polinómios em memória;
#     0. Sair da aplicação

# %%
resPol = []
def criapolinomio():
    polinomios = int(input("Número de polinómios que quer introduzir"))
    while polinomios > 0:
        resMon =[]
        monomios = int(input("quantos monómios tem o polinómio?"))
        while monomios > 0:
            coeficiente = float(input("Indique o coeficiente"))
            expoente = int(input("Indique o expoente")) 
            monomios = monomios - 1
            if coeficiente != 0:
                resMon.append((coeficiente, expoente))
        resPol.append(resMon)
        polinomios = polinomios - 1
    print(resPol)
    return resPol

def guardarpolinomio(fnome):
    fpol = open(fnome, "w")
    for polinomio in resPol:
        for monomio in polinomio:
            coeficiente, expoente = monomio
            fpol.write(str(coeficiente) + ", " + str(expoente) + " |")
        fpol.write("\n") 
    fpol.close
    return

def lerpolinomio(fnome):
    res = []
    fpol = open(fnome)
    for linha in fpol:
        polinomio = []
        termos = linha.split("|")
        termos.remove ("\n") 
        for t in termos:
            monomio = t.split(",")
            polinomio.append((float(monomio[0]), int(monomio[1])))
        res.append(polinomio)
    fpol.close()
    return res

def listarpolinomio(fnome):
    n = 1
    fpol = open(fnome)
    print ("------- ordem -------|------ monómio ------")
    print ("---------------------|---------------------")
    for linha in fpol:
        polinomio = ()
        termo = linha.split("|") 
        termo.remove ("\n") 
        res = ""
        for t in termos:
            monomio = t.split(",")
            coeficiente, expoente = monomio
            if float(coeficiente) < 0:
                res = (f"{res}{str(coeficiente)}")
            else:
                res = (f"{res}+{str(coeficiente)}")
            if float(coeficiente) != 0:
                if expoente != 0:
                    res = (f"{res}x^{str(expoente)}")    
                    polinomio = (res)
        print (f"-------- {n} --------|----- {polinomio} -----")
        n = n + 1
        print ("-------------------|---------------------")
    fpol.close()

def calcularpolinomio(p, x):
    res = 0
    for monomio in p:
        coeficiente, expoente = monomio
        res = res + (x**expoente)*coeficiente 
    return res

def listarpolinomiograu(fnome):
    n = 1
    fpol = open(fnome)
    print ("---- ordem ----|---- grau ----|---- monómio ----")
    print ("---------------|--------------|-----------------")
    for linha in fpol:
        polinomio = ()
        termos = linha.split("|") #tira o |
        termos.remove ("\n") 
        res = ""
        maior = 0
        for t in termos:
            monomio = t.split(",")
            coeficiente, expoente = monomio
            if float(coef) < 0:
                res = (f"{res}{str(coeficiente)}")
            else:
                res = (f"{res}+{str(coeficiente)}")
            if float(coeficiente) != 0:
                if expoente != 0:
                    res = (f"{res}x^{str(expoente)}")    
                    polinomio = (res)
            if int(expoente) > int(maior):
                maior = expoente
        print (f"------ {n} ------|---- {maior} ----|--- {polinomio} ---")
        n = n + 1
        print ("---------------|--------------|-----------------")
    fpol.close()

def graupolinomio(fnome):
    maior = 0
    ordem = 0
    m =()
    n = 1
    fpol = open(fnome)
    for linha in fpol:
        polinomio = ()
        termos = linha.split("|") 
        termos.remove ("\n") 
        res = ""
        ordem = ordem + 1
        for t in termos:
            monomio = t.split(",")    
            coeficiente, expoente = monomio
            if int(expoente) > int(maior):
                maior = expoente
                m = (maior, ordem)
    print(m)

def derivada1(fnome):
    fpol = open(fnome)
    print ("-------- polinómio --------|-------- derivada --------")
    print ("---------------------------|--------------------------")
    for linha in fpol:
        polinomio = []
        termos = linha.split("|") 
        termos.remove ("\n")
        for t in termos:
            monomio = t.split(",")
            polinomio.append((float(monomio[0]), int(monomio[1])))
            res = ""
            derivada = []
            for n in poli:
                coeficiente, expoente = n
                if float(coeficiente) < 0:
                    res = (f"{res}{str(coeficiente)}")
                else:
                    res = (f"{res}+{str(coeficiente)}")
                if float(coeficiente) != 0:
                    if expoente != 0:
                        res = (f"{res}x^{str(expoente)}")

                coeficiente = coeficiente * expoente
                expoente = expoente - 1
                derivada.append((coeficiente, expoente))
                resx = ""
                for x in derivada:  
                    coeficientex, expoentex = x
                    if float(coeficientex) < 0:
                        resx = (f"{resx}{str(coeficiented)}")
                    elif float(coeficiented) > 0:
                        resx = (f"{resx}+{str(coeficientex)}")
                    if float(coeficientex) != 0:
                        if expoentex != 0:
                            resx = (f"{resx}x^{str(expoentex)}")
        print (f"---------- {res} ----------|--------- {resx} ---------")
        print ("---------------------------|--------------------------")
    fpol.close()

def soma(pol1, pol2):
    coeficienteres = 0
    expoenteres = 0
    npol = ()
    soma = []
    for coeficiente1, expoente1 in polinomio1:
        encontrado = False
        for coeficiente2, expoente2 in polinomio2:
            if expoente1 == expoente2:
                coeficienteres = coeficiente1 +coeficiente2
                npol = (coeficienteres, expoente1)
                soma.append(npol)
                encontrado = True
        if encontrado == False:
            npol = (coeficiente1, expoente1)
            soma.append(npol) 
    for coeficiente2, expoente2 in polinomio2:
        encontrado = False
        for coeficiente1, expoente1 in polinomio1:
            if expoente1 == expoente2:
                encontrado = True 
        if encontrado == False:
            npol = (coeficiente2, expoente2)
            soma.append(npol)

    x = sorted(soma, reverse = True, key= lambda x: x[1])
    res = ""
    for n in x:
        coeficiente, expoente = n
        if float(coeficiente) != 0:
            if expoente != 0:
                res = (f"{res}x^{str(expoente)}")
        if float(coeficiente) < 0:
            res = (f"{res}{str(coeficiente)}")
        else:
            res = (f"{res}+{str(coeficiente)}")

    print (res)

def desenhargráfico(p):
    import matplotlib.pyplot as plt
    import numpy as np 
    coeficientes = []
    for monomio in p:
        coeficiente, expoente = monomio
        coeficientes.append(coeficiente)
    x = np.linspace(-10, 10, 400)  
    y = sum(coeficiente * x ** expoente for expoente, coeficiente in enumerate(coeficientes))

    plt.plot(x, y, label=f"Polinômio: {p} ")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Gráfico de um Polinômio")
    plt.grid(True)
    plt.legend()
    plt.show()

opcao = -1
while opcao != 0:
    print("""Escolha uma opção:
    1 -  Criar um polinómio;
    2 -  Ler uma lista de polinómios de um ficheiro;
    3 -  Listar polinómios em memória;
    4 -  Calcular o valor de um polinómio num ponto;
    5 -  Listar polinómios em conjunto com o seu grau;
    6 -  Listar o polinómio em memória de maior grau;
    7 -  Listar os polinómios em memória juntamente com as suas respetivas derivadas;
    8 -  Somar dois polinómios;
    9 -  Traçar um gráfico para o polinómio;
    10 - Gravar num ficheiro os polinómios em memória;
    0 -  Sair""")
    opcao = int(input("Selecione a opção que quer"))
    if opcao == 1:
        criapolinomio()
    if opcao == 2:
        print(lerpolinomio("polinomios2.txt"))
    if opcao == 3:
        listarpolinomio("polinomios2.txt")
    if opcao == 4:
        p = int(input("Qual é a ordem do polinómio que quer?"))
        x = int(input("Em que ponto o quer calcular?"))
        print(calcularpolinomio(lerpolinomio("polinomios2.txt")[(p-1)], x))
    if opcao == 5:
        listarpolinomiograu("polinomios2.txt")
    if opcao == 6:
        graupolinomio("polinomios2.txt")
    if opcao == 7:
        derivada1("polinomios2.txt")
    if opcao == 8:
        pol1 = int(input("Escolha um polinómio"))
        pol2 = int(input("Escolha outro polinómio"))
        soma(calcularpolinomio(lerpolinomio("polinomios2.txt")[(pol1-1)], calcularpolinomio(lerpolinomio("polinomios2.txt")[(pol2-1)])))
    if opcao == 9:
        p = int(input("Qual é a ordem do polinómio que quer?"))
        desenhargráfico(lerpolinomio("polinomios2.txt")[(p-1)]) 
    if opcao == 10:
        guardarpolinomio("polinomios2.txt")
# Out:
# Escolha uma opção:
#     1 -  Criar um polinómio;
#     2 -  Ler uma lista de polinómios de um ficheiro;
#     3 -  Listar polinómios em memória;
#     4 -  Calcular o valor de um polinómio num ponto;
#     5 -  Listar polinómios em conjunto com o seu grau;
#     6 -  Listar o polinómio em memória de maior grau;
#     7 -  Listar os polinómios em memória juntamente com as suas respetivas derivadas;
#     8 -  Somar dois polinómios;
#     9 -  Traçar um gráfico para o polinómio;
#     10 - Gravar num ficheiro os polinómios em memória;
#     0 -  Sair
# ---------------------------------------------------------------------------
#
# FileNotFoundError                         Traceback (most recent call last)
#
# c:\Users\Ana Rita Sousa\AppData\Local\Temp\Tempadccfba5-0ebd-42f7-977f-f2d56d331a9a_AulaP7-20231023.ipynb (1).zip\AulaP7-20231023.ipynb Cell 26 line 2
#
#     <a href='vscode-notebook-cell:/c%3A/Users/Ana%20Rita%20Sousa/AppData/Local/Temp/Tempadccfba5-0ebd-42f7-977f-f2d56d331a9a_AulaP7-20231023.ipynb%20%281%29.zip/AulaP7-20231023.ipynb#X34sZmlsZQ%3D%3D?line=242'>243</a>     p = int(input("Qual é a ordem do polinómio que quer?"))
#
#     <a href='vscode-notebook-cell:/c%3A/Users/Ana%20Rita%20Sousa/AppData/Local/Temp/Tempadccfba5-0ebd-42f7-977f-f2d56d331a9a_AulaP7-20231023.ipynb%20%281%29.zip/AulaP7-20231023.ipynb#X34sZmlsZQ%3D%3D?line=243'>244</a>     x = int(input("Em que ponto o quer calcular?"))
#
# --> <a href='vscode-notebook-cell:/c%3A/Users/Ana%20Rita%20Sousa/AppData/Local/Temp/Tempadccfba5-0ebd-42f7-977f-f2d56d331a9a_AulaP7-20231023.ipynb%20%281%29.zip/AulaP7-20231023.ipynb#X34sZmlsZQ%3D%3D?line=244'>245</a>     print(calcularpolinomio(lerpolinomio("polinomios2.txt")[(p-1)], x))
#
#     <a href='vscode-notebook-cell:/c%3A/Users/Ana%20Rita%20Sousa/AppData/Local/Temp/Tempadccfba5-0ebd-42f7-977f-f2d56d331a9a_AulaP7-20231023.ipynb%20%281%29.zip/AulaP7-20231023.ipynb#X34sZmlsZQ%3D%3D?line=245'>246</a> if opcao == 5:
#
#     <a href='vscode-notebook-cell:/c%3A/Users/Ana%20Rita%20Sousa/AppData/Local/Temp/Tempadccfba5-0ebd-42f7-977f-f2d56d331a9a_AulaP7-20231023.ipynb%20%281%29.zip/AulaP7-20231023.ipynb#X34sZmlsZQ%3D%3D?line=246'>247</a>     listarpolinomiograu("polinomios2.txt")
#
#
#
# c:\Users\Ana Rita Sousa\AppData\Local\Temp\Tempadccfba5-0ebd-42f7-977f-f2d56d331a9a_AulaP7-20231023.ipynb (1).zip\AulaP7-20231023.ipynb Cell 26 line 3
#
#      <a href='vscode-notebook-cell:/c%3A/Users/Ana%20Rita%20Sousa/AppData/Local/Temp/Tempadccfba5-0ebd-42f7-977f-f2d56d331a9a_AulaP7-20231023.ipynb%20%281%29.zip/AulaP7-20231023.ipynb#X34sZmlsZQ%3D%3D?line=27'>28</a> def lerpolinomio(fnome):
#
#      <a href='vscode-notebook-cell:/c%3A/Users/Ana%20Rita%20Sousa/AppData/Local/Temp/Tempadccfba5-0ebd-42f7-977f-f2d56d331a9a_AulaP7-20231023.ipynb%20%281%29.zip/AulaP7-20231023.ipynb#X34sZmlsZQ%3D%3D?line=28'>29</a>     res = []
#
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Ana%20Rita%20Sousa/AppData/Local/Temp/Tempadccfba5-0ebd-42f7-977f-f2d56d331a9a_AulaP7-20231023.ipynb%20%281%29.zip/AulaP7-20231023.ipynb#X34sZmlsZQ%3D%3D?line=29'>30</a>     fpol = open(fnome)
#
#      <a href='vscode-notebook-cell:/c%3A/Users/Ana%20Rita%20Sousa/AppData/Local/Temp/Tempadccfba5-0ebd-42f7-977f-f2d56d331a9a_AulaP7-20231023.ipynb%20%281%29.zip/AulaP7-20231023.ipynb#X34sZmlsZQ%3D%3D?line=30'>31</a>     for linha in fpol:
#
#      <a href='vscode-notebook-cell:/c%3A/Users/Ana%20Rita%20Sousa/AppData/Local/Temp/Tempadccfba5-0ebd-42f7-977f-f2d56d331a9a_AulaP7-20231023.ipynb%20%281%29.zip/AulaP7-20231023.ipynb#X34sZmlsZQ%3D%3D?line=31'>32</a>         polinomio = []
#
#
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#
#     279 if file in {0, 1, 2}:
#
#     280     raise ValueError(
#
#     281         f"IPython won't let you open fd={file} by default "
#
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#
#     283         "you can use builtins' open."
#
#     284     )
#
# --> 286 return io_open(file, *args, **kwargs)
#
#
#
# FileNotFoundError: [Errno 2] No such file or directory: 'polinomios2.txt'
